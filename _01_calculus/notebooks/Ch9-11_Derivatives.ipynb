# %% [markdown]
# ### Derivatives - Calculus Chapters 10-11

# %%
# Load necessary libraries
from sympy import symbols, diff, simplify, Rational, solve, pprint
from sympy import Symbol
alpha = Symbol('α')
beta = Symbol('β')
gamma = Symbol('γ')
delta = Symbol('δ')
theta = Symbol('θ')
sigma = Symbol('σ')
kappa = Symbol('κ')
mu = Symbol('μ')
rho = Symbol('ρ')
init_session()  # For better output formatting in Jupyter Notebooks
# Out:
# IPython console for SymPy 1.14.0 (Python 3.14.0-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.14.0/

# %%
# Grok's example: f(x) = (x^2 +1)/(x^3 - 2x); f' = [(2x)(x^3 - 2x) - (x^2 + 1)(3x^2 - 2)]/(x^3 - 2x)^2

from sympy import *
x = symbols('x')
f = (x**2 + 1) / (x**3 - 2*x)
df = diff(f, x)
df_simplified = simplify(df)

print("f'(x) =")
df_simplified
# Out:
# f'(x) =
#     4      2
#  - x  - 5⋅x  + 2
# ──────────────────
#  2 ⎛ 4      2    ⎞
# x ⋅⎝x  - 4⋅x  + 4⎠

# %% [markdown]
# ##### Chapter 10 -Rules for Differentiating Functions - Supplementary Problems

# %% [raw]
# All problems have been previously solved by hand and verified.

# %%
# 27. y = x^5 + 5X^4 -10x^2 + 6; dy/dx = 5x^4 + 20x^3 - 20x
from sympy import symbols, diff
x = symbols('x')
y = x**5 + 5*x**4 - 10*x**2 + 6
y_prime = diff(y, x)
y_prime = simplify(y_prime)
pprint("y_prime =")
y_prime
# Out:
# y_prime =
#     ⎛ 3      2    ⎞
# 5⋅x⋅⎝x  + 4⋅x  - 4⎠

# %%
# 28. y = 3x^(1/2) - (x)^(3/2) + 2x^(-1/2); dy/dx = (3/2)x^(-1/2) - (3/2)x^(1/2) - x^(-3/2)
x = symbols('x')
y = 3*x**Rational(1,2) - x**Rational(3,2) + 2*x**Rational(-1,2)
y_prime = diff(y, x)
y_prime = simplify(y_prime)
pprint(y_prime)
# Out:
#      2
# - 3⋅x  + 3⋅x - 2
# ────────────────
#         3/2
#      2⋅x

# %%
# 29. y = 1/2x^2 + 4/x^(1/2); dy/dx = -x^(-3) - 2*x^(-3/2)
x = symbols('x')
y = Rational(1,2)*x**(-2) + 4/x**Rational(1,2)
y_prime = diff(y, x)        
pprint(y_prime)
# Out:
#   1     2
# - ── - ────
#    3    3/2
#   x    x

# %%
# 30. y = sqrt(2x) + 2*sqrt(x); dy/dx = 1/sqrt(2x) + 1/sqrt(x) = (sqrt(2) + 2)/(2*sqrt(x)) = (1 + sqrt(2))/(sqrt(2x))
x = symbols('x')
y = sqrt(2*x) + 2*sqrt(x)
y_prime = diff(y, x)
y_prime = simplify(y_prime)
y_prime
# Out:
# √2 + 2
# ──────
#  2⋅√x

# %%
# 31. f(t) = 2/t^(1/2) + 6/(t)^(1/3); f'(t) = -1/(2t^(3/2)) - 2/(t^(4/3))
t = symbols('t')
f = 2/t**Rational(1,2) + 6/t**Rational(1,3)
f_prime = diff(f, t)
f_prime = simplify(f_prime)
f_prime
# Out:
#    1      2
# - ──── - ────
#    3/2    4/3
#   t      t

# %%
# 32.  y = (1 -5x)**6; dy/dx = -30(1 - 5x)**5
x = symbols('x')
y = (1 - 5*x)**6
y_prime = diff(y, x)
y_prime = simplify(y_prime)
pprint(y_prime)
# Out:
#             5
# 30⋅(5⋅x - 1)

# %%
# 33. f(x) = (3x - x^3 + 1)^4; f'(x) = 4(3x - x^3 + 1)^3(3 - 3x^2)
x = symbols('x')
f = (3*x - x**3 + 1)**4
f_prime = diff(f, x)
f_prime = simplify(f_prime)
print("y' =", f_prime)
# Out:
# y' = 12*(1 - x**2)*(-x**3 + 3*x + 1)**3

# %%
#34. y = (3 +4x - x^2)^(1/2); dy/dx = (1/2)(3 + 4x - x^2)^(-1/2)(4 - 2x) = (2 -x)/(3 + 4x - x^2)^(1/2)
x = symbols('x')
y = (3 + 4*x - x**2)**(1/2)
y_prime = diff(y, x)
y_prime = simplify(y_prime)
print("y' =", y_prime)
# Out:
# y' = (2.0 - 1.0*x)/(-x**2 + 4*x + 3)**0.5

# %%
# 35. θ = (3r +2)/(2r + 3); dθ/dr = 5/(2r + 3)^2
r = symbols('r')
θ = (3*r + 2)/(2*r + 3)
θ_prime = diff(θ, r)
θ_prime = simplify(θ_prime)
print("θ'=", θ_prime)
# Out:
# θ'= 5/(2*r + 3)**2

# %%
# 36. y = (x/(1+x))^5; dy/dx = 5(x/(1 + x))^4(1/(1 + x)^2)
x = symbols('x')
y = (x/(1 + x))**5
y_prime = diff(y, x)
y_prime = simplify(y_prime)
pprint(y_prime)
# Out:
#      4
#   5⋅x
# ────────
#        6
# (x + 1)

# %%
# 37. y = 2x^2*(2-x)^(1/2); dy/dx =  
x = symbols('x')
y = (2*x**2)*(2 - x)**(1/2)
y_prime = diff(y, x)
prime = simplify(y_prime)
y_prime
# Out:
#        2        -0.5              0.5
# - 1.0⋅x ⋅(2 - x)     + 4⋅x⋅(2 - x)

# %%
# 38. f(x) = x*(3-2x^2)^1/2; f'(x) = (3 - 2x^2)^(1/2) - 2x^2/(3 - 2x^2)^(1/2)           
x = symbols('x')
f = x*(3 - 2*x**2)**Rational(1,2)
f_prime = diff(f, x)
f_prime = simplify(f_prime)
f_prime
# Out:
#          2
#   3 - 4⋅x
# ─────────────
#    __________
#   ╱        2
# ╲╱  3 - 2⋅x

# %%
# 45. y = ((x^2-1)/(2x^3+1))^4; dy/dx = 4((x^2 - 1)/(2x^3 + 1))^3 * [(2x(2x^3 + 1) - (x^2 - 1)(6x^2))/(2x^3 + 1)^2]
x = symbols('x')      
y = ((x**2 - 1)/(2*x**3 + 1))**4
y_prime = diff(y, x)
y_prime = simplify(y_prime)
y_prime
# Out:
#             3
#     ⎛ 2    ⎞  ⎛   3       ⎛ 2    ⎞    ⎞
# 8⋅x⋅⎝x  - 1⎠ ⋅⎝2⋅x  - 3⋅x⋅⎝x  - 1⎠ + 1⎠
# ───────────────────────────────────────
#                         5
#               ⎛   3    ⎞
#               ⎝2⋅x  + 1⎠

# %%
# 63. inverse x^3 = y^1/3 
from sympy import symbols, simplify, solve

x = symbols('x')
f = x**3
y = symbols('y')

# Solve y = f(x) for x
inverse_expr = simplify(solve(y - f, x)[0])

print("Inverse function:")
pprint(inverse_expr)

y_prime = diff(inverse_expr, y)
y_prime = simplify(y_prime)
print("\ny_prime =")
y_prime
# Out:
# Inverse function:
# 3 ___
# ╲╱ y
#
# y_prime =
#   1
# ──────
#    2/3
# 3⋅y

# %%
# 64. inverse f(x) = (2x - 1)/(x + 2) 
from sympy import symbols, simplify, solve

x = symbols('x')
f = (2*x - 1)/(x + 2)
y = symbols('y')

# Solve y = f(x) for x
inverse_expr = simplify(solve(y - f, x)[0])

pprint("Inverse function:")
inverse_expr
# Out:
# Inverse function:
# -2⋅y - 1
# ────────
#  y - 2

# %%
y_prime = diff(inverse_expr, y)
y_prime = simplify(y_prime)
print("y_prime =")
y_prime
# Out:
# y_prime =
#    5
# ────────
#        2
# (y - 2)

# %% [markdown]
# ##### Chapter 11 - Implicit Differentiation

# %%
# Solved problems
# 1. Implicit Differentiation
# (x**2)*y - x*y**2 + x**2 + y**2 = 0

from sympy import symbols, diff, simplify, pprint

# Define variables
x, y = symbols('x y')

# Given implicit equation: F(x, y) = 0
expr = x**2 * y - x * y**2 + x**2 + y**2

# Step 1: Compute partial derivatives
F_x = diff(expr, x)   # ∂F/∂x
F_y = diff(expr, y)   # ∂F/∂y

# Step 2: First derivative: dy/dx = -F_x / F_y
dy_dx = simplify(-F_x / F_y)

print("dy/dx:")
dy_dx
# Out:
# dy/dx:
#                 2
# -2⋅x⋅y - 2⋅x + y
# ─────────────────
#  2
# x  - 2⋅x⋅y + 2⋅y

# %%
# 2. Second Derivative
# Given implicit equation: x**2 - x*y + y**2 - 3 = 0

from sympy import symbols, diff, simplify, pprint

# Define variables
x, y = symbols('x y')

# Given implicit equation: F(x, y) = 0
expr = x**2 - x*y + y**2 - 3

# Step 1: Compute partial derivatives
F_x = diff(expr, x)   # ∂F/∂x
print("F_x:", F_x)
F_y = diff(expr, y)   # ∂F/∂y
print("F_y:", F_y)

# Step 2: First derivative: dy/dx = -F_x / F_y
dy_dx = simplify(-F_x / F_y)

# print("dy/dx:")
dy_dx

# Step 3: Second derivative using the formula for implicit differentiation
# d²y/dx² = - (∂²F/∂x² + 2(∂²F/∂x∂y)(dy/dx) + ∂²F/∂y²(dy/dx)²) / (∂F/∂y)

F_xx = diff(F_x, x)        # ∂²F/∂x²
F_xy = diff(F_x, y)        # ∂²F/∂x∂y
F_yy = diff(F_y, y)        # ∂²F/∂y²

numerator = F_xx + 2*F_xy*dy_dx + F_yy*(dy_dx)**2
d2y_dx2 = simplify(-numerator / F_y)

print("\nd²y/dx²:")
d2y_dx2
# Out:
# F_x: 2*x - y
# F_y: -x + 2*y
#
# d²y/dx²:
#   ⎛                                2            2⎞
# 2⋅⎝(-2⋅x + y)⋅(x - 2⋅y) + (x - 2⋅y)  + (2⋅x - y) ⎠
# ──────────────────────────────────────────────────
#                              3
#                     (x - 2⋅y)

# %%
# ------------------------------------------------------------
#  SymPy – first and second derivatives of the implicit curve
#  f(x,y) = x² - x y + y² - 3 = 0
# ------------------------------------------------------------

import sympy as sp

# ------------------------------------------------------------------
# 1. Define symbols and the implicit function
# ------------------------------------------------------------------
x, y = sp.symbols('x y', real=True)
f = x**2 - x*y + y**2 - 3

print("Implicit equation:")
sp.pprint(f)
print("\n" + "="*60 + "\n")

# ------------------------------------------------------------------
# 2. First partial derivatives
# ------------------------------------------------------------------
df_dx = sp.diff(f, x)
df_dy = sp.diff(f, y)

print("First partial derivatives:")
print("∂f/∂x =", end=" ")
sp.pprint(df_dx)
print("∂f/∂y =", end=" ")
sp.pprint(df_dy)
print("\n" + "="*60 + "\n")

# ------------------------------------------------------------------
# 3. Second partial derivatives (Hessian)
# ------------------------------------------------------------------
d2f_dx2 = sp.diff(df_dx, x)      # f_xx
d2f_dxdy = sp.diff(df_dx, y)     # f_xy  (same as f_yx)
d2f_dy2 = sp.diff(df_dy, y)      # f_yy

print("Second partial derivatives:")
print("∂²f/∂x²  =", end=" ")
sp.pprint(d2f_dx2)
print("∂²f/∂x∂y =", end=" ")
sp.pprint(d2f_dxdy)
print("∂²f/∂y²  =", end=" ")
sp.pprint(d2f_dy2)
print("\n" + "="*60 + "\n")

# ------------------------------------------------------------------
# 4. (Optional) Evaluate at a point on the curve
# ------------------------------------------------------------------
# Find a numeric point that satisfies f(x,y)=0, e.g. (x=1, y=1)
point = {x: 1, y: 1}
if f.subs(point) == 0:
    print(f"Evaluating at the point ({point[x]}, {point[y]}):")
    print("  f      =", f.subs(point))
    print("  ∂f/∂x  =", df_dx.subs(point))
    print("  ∂f/∂y  =", df_dy.subs(point))
    print("  ∂²f/∂x² =", d2f_dx2.subs(point))
    print("  ∂²f/∂x∂y=", d2f_dxdy.subs(point))
    print("  ∂²f/∂y² =", d2f_dy2.subs(point))
else:
    print("Chosen point does not lie on the curve – skipping numeric evaluation.")

# ------------------------------------------------------------------
# 5. (Optional) Lambdify for fast numeric evaluation
# ------------------------------------------------------------------
# Convert symbolic expressions to NumPy-callable functions
df_dx_num = sp.lambdify((x, y), df_dx, 'numpy')
df_dy_num = sp.lambdify((x, y), df_dy, 'numpy')
d2f_dx2_num = sp.lambdify((x, y), d2f_dx2, 'numpy')
d2f_dxdy_num = sp.lambdify((x, y), d2f_dxdy, 'numpy')
d2f_dy2_num = sp.lambdify((x, y), d2f_dy2, 'numpy')

# Example usage with NumPy arrays
import numpy as np
X = np.array([0.0, 1.0, 2.0])
Y = np.array([3.0, 1.0, 0.0])      # note: not necessarily on the curve
print("\nNumeric evaluation at points (X,Y):")
print("∂f/∂x  =", df_dx_num(X, Y))
print("∂f/∂y  =", df_dy_num(X, Y))
print("∂²f/∂x² =", d2f_dx2_num(X, Y))
print("∂²f/∂x∂y=", d2f_dxdy_num(X, Y))
print("∂²f/∂y² =", d2f_dy2_num(X, Y))
# Out:
# Implicit equation:
#  2          2
# x  - x⋅y + y  - 3
#
# ...
#
# First partial derivatives:
# ∂f/∂x = 2⋅x - y
# ∂f/∂y = -x + 2⋅y
#
# ...
#
# Second partial derivatives:
# ∂²f/∂x²  = 2
# ∂²f/∂x∂y = -1
# ∂²f/∂y²  = 2
#
# ...
#
# Chosen point does not lie on the curve – skipping numeric evaluation.
#
# Numeric evaluation at points (X,Y):
# ∂f/∂x  = [-3.  1.  4.]
# ∂f/∂y  = [ 6.  1. -2.]
# ∂²f/∂x² = 2
# ∂²f/∂x∂y= -1
# ∂²f/∂y² = 2

# %%
# Define variables
x, y = symbols('x y')

# Given implicit equation: F(x, y) = 0
expr = (2*x-y)/(x-2*y)

# Step 1: Compute partial derivatives
F_x = diff(expr, x)   # ∂F/∂x
F_y = diff(expr, y)   # ∂F/∂y

# Step 2: First derivative: dy/dx = -F_x / F_y
dy_dx = simplify(-F_x / F_y)

print("dy/dx:")
dy_dx
# Out:
# dy/dx:
# y
# ─
# x
