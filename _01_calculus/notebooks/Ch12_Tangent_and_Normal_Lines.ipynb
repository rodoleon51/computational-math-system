# %%
# Load necessary libraries
import sys
sys.path.append('utils')
from tangent_tools import tangent_normal

import sympy as sp
import numpy as np
import math
from fractions import Fraction
from sympy import symbols, diff, simplify, Rational, solve, pprint
from sympy import Symbol
alpha = Symbol('α')
beta = Symbol('β')
gamma = Symbol('γ')
delta = Symbol('δ')
theta = Symbol('θ')
sigma = Symbol('σ')
kappa = Symbol('κ')
mu = Symbol('μ')
rho = Symbol('ρ')
x, y, t, theta = sp.symbols('x y t theta')

sp.init_printing()  # For better output formatting in Jupyter Notebooks

# %%
# 12.1 Tangent Lines
tangent_normal(f = x**3 - 2*x**2 + 4, x0=2, y0=4)
# Out:
# Tangent and Normal at point (2.0, 4.0)
# Slope of tangent: 4
# Tangent line: Eq(y, 4*x - 4)
# Normal line : Eq(y, 9/2 - x/4)
# {'type': 'explicit',
#  'point': (2.0, 4.0),
#  'slope': 4,
#  'tangent': Eq(y, 4*x - 4),
#  'normal': Eq(y, 9/2 - x/4),
#  'dy_dx': 3*x**2 - 4*x}

# %%
# 12.2
tangent_normal(implicit= x**2 + 3*x*y + y**2 - 5, x0=1, y0=1, show_plot=True)
# Out:
# Tangent and Normal at point (1, 1)
# Slope of tangent: -1
# Tangent line: Eq(y - 1, 1 - x)
# Normal line : Eq(y - 1, x - 1)
# {'type': 'implicit',
#  'point': (1, 1),
#  'slope': -1,
#  'tangent': Eq(y - 1, 1 - x),
#  'normal': Eq(y - 1, x - 1)}
